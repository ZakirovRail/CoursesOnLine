# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2 = pd.DataFrame.from_dict({'a':[1,2], 'b':[3, 4]})

# %%
df2
# Out:
#    a  b
# 0  1  3
# 1  2  4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail(2)
# Out:
#      PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 889          890         1       1  Behr, Mr. Karl Howell  male  26.0      0
# 890          891         0       3    Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket   Fare Cabin Embarked
# 889      0  111369  30.00  C148        C
# 890      0  370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df[['Name', 'Age']].head(3)
# Out:
#                                                 Name   Age
# 0                            Braund, Mr. Owen Harris  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                             Heikkinen, Miss. Laina  26.0

# %%
df.loc[[0, 5, 10, 15], ['Name', 'Age']]
# Out:
#                                 Name   Age
# 0            Braund, Mr. Owen Harris  22.0
# 5                   Moran, Mr. James   NaN
# 10   Sandstrom, Miss. Marguerite Rut   4.0
# 15  Hewlett, Mrs. (Mary D Kingcome)   55.0

# %%
df.iloc[[0, 5, 10, 15], [0, 1]]
# Out:
#     PassengerId  Survived
# 0             1         0
# 5             6         0
# 10           11         1
# 15           16         1

# %%
df.iloc[5:11, :3]
# Out:
#     PassengerId  Survived  Pclass
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3

# %%
df[df['Age'] > 18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'] > 18
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
type(df['Age'] > 18)
# Out:
# pandas.core.series.Series

# %%
df[df['Age'].isin([5,10,15])]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 22            23         1       3              McGowan, Miss. Anna "Annie"
# 58            59         1       2             West, Miss. Constance Mirium
# 233          234         1       3           Asplund, Miss. Lillian Gertrud
# 352          353         0       3                       Elias, Mr. Tannous
# 419          420         0       3                Van Impe, Miss. Catharina
# 448          449         1       3           Baclini, Miss. Marie Catherine
# 689          690         1       1        Madill, Miss. Georgette Alexandra
# 777          778         1       3            Emanuel, Miss. Virginia Ethel
# 819          820         0       3             Skoog, Master. Karl Thorsten
# 830          831         1       3  Yasbeck, Mrs. Antoni (Selini Alexander)
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df[df['Age'].isin([15])]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 22            23         1       3              McGowan, Miss. Anna "Annie"
# 352          353         0       3                       Elias, Mr. Tannous
# 689          690         1       1        Madill, Miss. Georgette Alexandra
# 830          831         1       3  Yasbeck, Mrs. Antoni (Selini Alexander)
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
#         Sex   Age  SibSp  Parch  Ticket      Fare Cabin Embarked
# 22   female  15.0      0      0  330923    8.0292   NaN        Q
# 352    male  15.0      1      1    2695    7.2292   NaN        C
# 689  female  15.0      0      1   24160  211.3375    B5        S
# 830  female  15.0      1      0    2659   14.4542   NaN        C
# 875  female  15.0      0      0    2667    7.2250   NaN        C

# %%
df[(df['Age'] == 5) | (df['Age'] == 10)]
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 58            59         1       2    West, Miss. Constance Mirium  female
# 233          234         1       3  Asplund, Miss. Lillian Gertrud  female
# 419          420         0       3       Van Impe, Miss. Catharina  female
# 448          449         1       3  Baclini, Miss. Marie Catherine  female
# 777          778         1       3   Emanuel, Miss. Virginia Ethel  female
# 819          820         0       3    Skoog, Master. Karl Thorsten    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 58    5.0      1      2  C.A. 34651  27.7500   NaN        S
# 233   5.0      4      2      347077  31.3875   NaN        S
# 419  10.0      0      2      345773  24.1500   NaN        S
# 448   5.0      2      1        2666  19.2583   NaN        C
# 777   5.0      0      0      364516  12.4750   NaN        S
# 819  10.0      3      2      347088  27.9000   NaN        S

# %%
df['Age'].notna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %% [markdown]
# Посчитать количество пропусков по возрасту

# %%
df['Age'].isna().sum()
# Out:
# 177

# %% [markdown]
# Вернуть список людей по которым мы знаем возраст

# %%
df.loc[df['Age'].notna(), 'Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 885                 Rice, Mrs. William (Margaret Norton)
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 714, dtype: object

# %% [markdown]
# sort people by age

# %%
df.sort_values('Age').head(5)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %% [markdown]
#  Сортировка по возарсту а потом по имени по мере убывания

# %%
df.sort_values(['Age', 'Name'], ascending=[False, True]).head(5)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0     27042  30.0000   A23        S
# 851  male  74.0      0      0    347060   7.7750   NaN        S
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C
# 116  male  70.5      0      0    370369   7.7500   NaN        Q

# %%
df2 = df.copy(deep=True)

# %% [markdown]
# объединить два DataFrame (к первой таблице добавить строки второй)

# %%
cdf1 = pd.concat([df, df2])

# %%
cdf1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# объединить два DataFrame столбцами (к столбцам первого добавить столбцы второго)

# %%
cdf2 = pd.concat([df, df2], axis=1)

# %%
cdf2.shape
# Out:
# (891, 24)

# %% [markdown]
# Создать новый временный DF с таким же кол-вом строк как и у оригинального

# %%
mdf = pd.DataFrame(index=df.index)

# %% [markdown]
# Добавить колонку PassangerId

# %%
mdf['PassengerId'] = df['PassengerId']

# %%
mdf['evenId'] = mdf['PassengerId'].apply(lambda x: x % 2 == 0)

# %%
mdf
# Out:
#      PassengerId  evenId
# 0              1   False
# 1              2    True
# 2              3   False
# 3              4    True
# 4              5   False
# ..           ...     ...
# 886          887   False
# 887          888    True
# 888          889   False
# 889          890    True
# 890          891   False
#
# [891 rows x 2 columns]

# %% [markdown]
# соединить две таблицы с использованием merge по условию inner

# %%
pd.merge(df, mdf, how='inner')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
